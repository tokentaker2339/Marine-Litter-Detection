# %%
import os
import time
import cv2
import numpy as np
from model.yolo_model import YOLO
# Out:
# Using TensorFlow backend.

# %%
def process_image(img):
    """Resize, reduce and expand image.

    # Argument:
        img: original image.

    # Returns
        image: ndarray(64, 64, 3), processed image.
    """
    image = cv2.resize(img, (416, 416),
                       interpolation=cv2.INTER_CUBIC)
    image = np.array(image, dtype='float32')
    image /= 255.
    image = np.expand_dims(image, axis=0)

    return image

# %%
def get_classes(file):
    """Get classes name.

    # Argument:
        file: classes name for database.

    # Returns
        class_names: List, classes name.

    """
    with open(file) as f:
        class_names = f.readlines()
    class_names = [c.strip() for c in class_names]

    return class_names

# %%
def draw(image, boxes, scores, classes, all_classes):
    """Draw the boxes on the image.

    # Argument:
        image: original image.
        boxes: ndarray, boxes of objects.
        classes: ndarray, classes of objects.
        scores: ndarray, scores of objects.
        all_classes: all classes name.
    """
    global cX, cY
    area = []
    cl_list = []
    cl_max = None
    for box, score, cl in zip(boxes, scores, classes):
        x, y, w, h = box

        top = max(0, np.floor(x + 0.5).astype(int))
        left = max(0, np.floor(y + 0.5).astype(int))
        right = min(image.shape[1], np.floor(x + w + 0.5).astype(int))
        bottom = min(image.shape[0], np.floor(y + h + 0.5).astype(int))
        
        if all_classes[cl] == 'bottle':
            area_temp = (top - right)*(left - bottom)
            area.append(area_temp)
            cl_list.append(cl)
    
    print(area)
    
    if len(area) != 0:  
        cl_max = np.argmax(area)
        
    print(cl_max)
    max_area_flag = 0
    for box, score, cl in zip(boxes, scores, classes):
        x, y, w, h = box

        top = max(0, np.floor(x + 0.5).astype(int))
        left = max(0, np.floor(y + 0.5).astype(int))
        right = min(image.shape[1], np.floor(x + w + 0.5).astype(int))
        bottom = min(image.shape[0], np.floor(y + h + 0.5).astype(int))
        
        
        print(max_area_flag)
        if all_classes[cl] == 'bottle':
            if max_area_flag == cl_max:
                cv2.rectangle(image, (top, left), (right, bottom), (0, 0, 255), 2)
                cv2.circle(image,center = (int((top+right)/2),int((left+bottom)/2)),radius = 5,color=(255,0,0),thickness = -1)
                cv2.putText(image, '{} {} '.format('Closest Target',all_classes[cl]),
                            (top, left - 6),
                            cv2.FONT_HERSHEY_SIMPLEX,
                            0.6, (0, 0, 255), 1,
                            cv2.LINE_AA)
                (cX,cY) = (int((top+right)/2),int((left+bottom)/2))
                
            else:
                cv2.rectangle(image, (top, left), (right, bottom), (0, 0, 0), 2)
                cv2.circle(image,center = (int((top+right)/2),int((left+bottom)/2)),radius = 5,color=(255,0,0),thickness = -1)
                cv2.putText(image, '{0}'.format(all_classes[cl]),
                            (top, left - 6),
                            cv2.FONT_HERSHEY_SIMPLEX,
                            0.6, (0, 0, 255), 1,
                            cv2.LINE_AA)  
            
            max_area_flag = max_area_flag + 1

        print('class: {0}, score: {1:.2f}'.format(all_classes[cl], score))
        print('box coordinate x,y,w,h: {0}'.format(box))

    print(len(area))
    if len(area) != 0:

        if cX > (image.shape[1]/2) + 0.15*image.shape[1]:
            cv2.putText(image, 'Steer Right',
                            (int(image.shape[1]/2),int(image.shape[0]/25)),
                            cv2.FONT_HERSHEY_SIMPLEX,
                            1.2, (255, 0, 0), 1,
                            cv2.LINE_AA)  

        elif cX < (image.shape[1]/2) - 0.15*image.shape[1]:
            cv2.putText(image, 'Steer Left',
                            (int(image.shape[1]/2),int(image.shape[0]/25)),
                            cv2.FONT_HERSHEY_SIMPLEX,
                            1.2, (255, 0, 0), 1,
                            cv2.LINE_AA) 
            #print('Rotate Laptop to the Left')

        else:
            cv2.putText(image, 'Head Straight',
                            (int(image.shape[1]/2),int(image.shape[0]/25)),
                            cv2.FONT_HERSHEY_SIMPLEX,
                            1.2, (255, 0, 0), 1,
                            cv2.LINE_AA) 
            #print('Head Straight')

    else:
        cv2.putText(image, 'No bottle detected',
                            (int(image.shape[1]/2),int(image.shape[0]/25)),
                            cv2.FONT_HERSHEY_SIMPLEX,
                            1.2, (255, 0, 0), 1,
                            cv2.LINE_AA) 
            #print('Head Straight')

    print()

# %%
def detect_image(image, yolo, all_classes):
    """Use yolo v3 to detect images.

    # Argument:
        image: original image.
        yolo: YOLO, yolo model.
        all_classes: all classes name.

    # Returns:
        image: processed image.
    """
    pimage = process_image(image)

    start = time.time()
    boxes, classes, scores = yolo.predict(pimage, image.shape)
    end = time.time()

    print('time: {0:.2f}s'.format(end - start))

    if boxes is not None:
        draw(image, boxes, scores, classes, all_classes)

    return image

# %%
def detect_video(yolo, all_classes):
    """Use yolo v3 to detect video.

    # Argument:
        video: video file.
        yolo: YOLO, yolo model.
        all_classes: all classes name.
    """
    camera = cv2.VideoCapture(0)
    cv2.namedWindow("detection", cv2.WINDOW_AUTOSIZE)
    #camera.set(cv2.CAP_PROP_FPS, 15)
    while True:
        res, frame = camera.read()

        if not res:
            break

        image = detect_image(frame, yolo, all_classes)
        cv2.imshow("detection", image)

        if cv2.waitKey(110) & 0xff == 27:
                break

    camera.release()
    cv2.destroyAllWindows()

# %%
yolo = YOLO(0.6, 0.5)
file = 'data/coco_classes.txt'
all_classes = get_classes(file)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\keras\engine\saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
if __name__ == "__main__":
    detect_video(yolo,all_classes)
    camera = cv2.VideoCapture(0)
    camera.release()
    cv2.destroyAllWindows()
# Out:
# time: 7.64s
# []
# None
# 0
# class: person, score: 1.00
# box coordinate x,y,w,h: [106.04522705  28.59334946 526.02897644 426.99279785]
# 0
#
# time: 1.94s
# []
# None
# 0
# class: person, score: 0.98
# box coordinate x,y,w,h: [ 47.55838394  14.78007317 556.12148285 451.06676102]
# 0
# class: person, score: 0.87
# box coordinate x,y,w,h: [194.61780548   9.84282017 179.9524498  299.94647026]
# 0
#
# time: 1.97s
# []
# None
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [169.97070312  19.01139736 236.99277878 446.47233009]
# 0
# class: person, score: 0.87
# box coordinate x,y,w,h: [ -3.17241669  97.61133671 225.32388687 385.37764549]
# 0
# class: person, score: 0.82
# box coordinate x,y,w,h: [409.38201904  12.87015438 233.62178802 452.79719353]
# 0
#
# time: 1.95s
# []
# None
# 0
# class: person, score: 1.00
# box coordinate x,y,w,h: [166.91257477   7.70762444 241.00522995 462.46318817]
# 0
# class: person, score: 0.87
# box coordinate x,y,w,h: [ -2.42619514 103.48608971 229.19294357 392.4385643 ]
# 0
#
# time: 1.98s
# []
# None
# 0
# class: person, score: 0.96
# box coordinate x,y,w,h: [259.09908295   8.61897469 310.24637222 456.39979362]
# 0
# class: person, score: 0.80
# box coordinate x,y,w,h: [ -2.34037399  58.24481964 250.12302399 438.20840836]
# 0
#
# time: 1.93s
# []
# None
# 0
# class: person, score: 0.97
# box coordinate x,y,w,h: [319.58187103  11.35076523 308.36463928 456.96656227]
# 0
# class: person, score: 0.73
# box coordinate x,y,w,h: [ -2.40621567  56.00453854 249.90875244 432.48198509]
# 0
#
# time: 1.94s
# []
# None
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [300.27364731   1.95563793 347.2296524  470.1895237 ]
# 0
# class: person, score: 0.66
# box coordinate x,y,w,h: [  3.94212723  60.19982815 326.85153961 427.05296516]
# 0
#
# time: 1.97s
# []
# None
# 0
# class: person, score: 0.98
# box coordinate x,y,w,h: [361.86096191   6.09838486 269.03657913 456.09209061]
# 0
# class: person, score: 0.77
# box coordinate x,y,w,h: [163.12440872  20.67146301 224.69974518 434.53828812]
# 0
#
# time: 1.97s
# []
# None
# 0
# class: person, score: 1.00
# box coordinate x,y,w,h: [283.14725876   0.5344677  358.72348785 475.79303741]
# 0
#
# time: 1.96s
# []
# None
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [280.21484375   3.20119858 359.66995239 471.25751495]
# 0
#
# time: 2.00s
# []
# None
# 0
# class: person, score: 0.98
# box coordinate x,y,w,h: [308.63790512   7.68844128 336.21669769 463.50331306]
# 0
# class: person, score: 0.81
# box coordinate x,y,w,h: [ -4.15244102 117.85121441 236.86441422 368.61159325]
# 0
# class: cell phone, score: 0.65
# box coordinate x,y,w,h: [157.77947426  79.94974136 214.13980484 317.1613884 ]
# 0
#
# time: 1.96s
# [89464]
# 0
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [323.05183411   4.14138794 319.59506989 476.36770248]
# 0
# class: bottle, score: 0.80
# box coordinate x,y,w,h: [171.78951263  28.47314358 212.34025955 421.23461723]
# 1
#
# time: 1.97s
# []
# None
# 0
# class: person, score: 0.88
# box coordinate x,y,w,h: [386.51313782   4.72281933 249.86148834 466.60640717]
# 0
# class: person, score: 0.61
# box coordinate x,y,w,h: [170.91205597  16.21232986 402.81425476 442.42406845]
# 0
#
# time: 2.00s
# []
# None
# 0
# class: person, score: 0.95
# box coordinate x,y,w,h: [404.99370575   5.95945358 234.70487595 460.95631599]
# 0
# class: person, score: 0.79
# box coordinate x,y,w,h: [236.67819977 -15.88444233 238.26873779 511.03122711]
# 0
# class: person, score: 0.65
# box coordinate x,y,w,h: [  5.48055649  74.90309715 320.00270844 419.83434677]
# 0
#
# time: 1.98s
# []
# None
# 0
# class: person, score: 0.95
# box coordinate x,y,w,h: [389.26792145  12.70334244 243.84782791 450.97063065]
# 0
#
# time: 1.96s
# []
# None
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [411.15951538   2.1946764  228.18101883 461.09172821]
# 0
# class: person, score: 0.89
# box coordinate x,y,w,h: [161.40287399  14.67071056 329.48558807 453.4146595 ]
# 0
#
# time: 1.99s
# [59787]
# 0
# 0
# class: person, score: 0.91
# box coordinate x,y,w,h: [175.59452057  18.43065262 316.1164093  436.7175293 ]
# 0
# class: bottle, score: 0.94
# box coordinate x,y,w,h: [396.07578278 206.98691368 218.86350632 280.37584305]
# 1
#
# time: 1.98s
# [65124]
# 0
# 0
# class: person, score: 0.80
# box coordinate x,y,w,h: [240.52875519  -5.01600266 271.6837883  413.54793549]
# 0
# class: person, score: 0.69
# box coordinate x,y,w,h: [509.28817749  -8.66490841 129.04612541 339.86769676]
# 0
# class: person, score: 0.61
# box coordinate x,y,w,h: [ -1.01476669  86.82899952 244.2506218  403.5599041 ]
# 0
# class: bottle, score: 0.98
# box coordinate x,y,w,h: [383.16814423 151.83581829 200.52999496 324.55080986]
# 1
#
# time: 2.01s
# [69216]
# 0
# 0
# class: bottle, score: 0.83
# box coordinate x,y,w,h: [392.22541809 168.24617386 223.96619797 309.09215927]
# 1
#
# time: 2.01s
# [87990]
# 0
# 0
# class: person, score: 0.70
# box coordinate x,y,w,h: [114.27402496   9.34013844 421.62635803 451.24505997]
# 0
# class: bottle, score: 0.96
# box coordinate x,y,w,h: [423.80565643  35.35112858 210.13963699 418.23689461]
# 1
#
# time: 1.97s
# [76814]
# 0
# 0
# class: person, score: 0.76
# box coordinate x,y,w,h: [129.45079803  17.81643391 386.67724609 449.81045723]
# 0
# class: bottle, score: 0.96
# box coordinate x,y,w,h: [436.80686951  74.83819485 192.92869568 398.3186245 ]
# 1
#
# time: 2.00s
# [40770]
# 0
# 0
# class: person, score: 0.89
# box coordinate x,y,w,h: [237.72367477  21.09018803 229.37702179 438.59164238]
# 0
# class: bottle, score: 0.99
# box coordinate x,y,w,h: [424.33959961 142.82320976 150.49554825 269.96126175]
# 1
#
# time: 1.94s
# [44688]
# 0
# 0
# class: person, score: 0.82
# box coordinate x,y,w,h: [149.03312683  12.58209229 358.57528687 459.66796875]
# 0
# class: person, score: 0.67
# box coordinate x,y,w,h: [ -4.4366169   92.46422768 242.1578598  389.99422073]
# 0
# class: bottle, score: 0.98
# box coordinate x,y,w,h: [436.53900146 183.42418671 168.38693619 266.07370377]
# 1
#
# time: 1.95s
# [48060]
# 0
# 0
# class: person, score: 0.94
# box coordinate x,y,w,h: [226.36672974  15.32096386 258.95925522 450.8809948 ]
# 0
# class: person, score: 0.67
# box coordinate x,y,w,h: [ -1.0790062   85.01635551 246.93454742 404.23587799]
# 0
# class: bottle, score: 0.90
# box coordinate x,y,w,h: [432.81215668 173.70730877 179.89374161 267.45223045]
# 1
#
# time: 1.98s
# []
# None
# 0
# class: person, score: 0.92
# box coordinate x,y,w,h: [234.12757874  10.12829304 239.84998703 459.68419075]
# 0
#
# time: 1.99s
# [52124]
# 0
# 0
# class: bottle, score: 0.67
# box coordinate x,y,w,h: [446.83174133  78.83522987 157.26557732 331.74139023]
# 1
#
# time: 2.03s
# time: 1.94s
# []
# None
# 0
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 23.90426636  46.78506374 583.96865845 457.12231636]
# 0
#
# time: 1.95s
# []
# None
# 0
# class: person, score: 0.97
# box coordinate x,y,w,h: [241.29974365  30.38815498 356.02043152 420.70135117]
# 0
# class: person, score: 0.66
# box coordinate x,y,w,h: [ 15.90894699  67.53650665 406.33644104 423.48026276]
# 0
#
# time: 1.95s
# []
# None
# 0
# class: person, score: 0.93
# box coordinate x,y,w,h: [170.15632629   6.82898998 481.96151733 471.90602303]
# 0
# class: person, score: 0.82
# box coordinate x,y,w,h: [ 21.56059265  51.60841942 406.81148529 443.65825653]
# 0
#
# time: 1.96s
# []
# None
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [  9.63630676  64.52957153 527.49759674 419.65181351]
# 0
#
# time: 1.97s
# []
# None
# 0
# class: person, score: 0.93
# box coordinate x,y,w,h: [ 12.74503708  80.48727036 408.03546906 401.19129181]
# 0
# class: person, score: 0.77
# box coordinate x,y,w,h: [166.20471954 -24.41265106 418.88725281 530.54363251]
# 0
#
# time: 1.97s
# []
# None
# 0
# class: person, score: 0.96
# box coordinate x,y,w,h: [184.57328796   6.24811649 388.0381012  476.11573219]
# 0
# class: person, score: 0.96
# box coordinate x,y,w,h: [  9.70914841  87.67599106 420.09361267 385.06999969]
# 0
#
# time: 1.97s
# []
# None
# 0
# class: person, score: 0.97
# box coordinate x,y,w,h: [ 21.57533646  82.96638966 507.80776978 400.58444023]
# 0
#
# time: 1.94s
# []
# None
# 0
# class: person, score: 0.98
# box coordinate x,y,w,h: [ 23.85753632  68.49161625 507.87601471 418.73734474]
# 0
# class: person, score: 0.68
# box coordinate x,y,w,h: [216.57224655  -4.17293072 208.1886673  423.93450737]
# 0
#
# time: 2.08s
# [86104]
# 0
# 0
# class: person, score: 0.98
# box coordinate x,y,w,h: [ 19.33578491  74.79000092 494.78507996 410.7567215 ]
# 0
# class: person, score: 0.63
# box coordinate x,y,w,h: [238.97241592  12.10370064 242.83367157 445.26783943]
# 0
# class: bottle, score: 0.75
# box coordinate x,y,w,h: [436.87389374  22.49957085 187.7831459  459.07871246]
# 1
#
# time: 2.00s
# []
# None
# 0
# class: person, score: 0.93
# box coordinate x,y,w,h: [ 27.13693619  73.75489712 492.28675842 411.95832253]
# 0
#
# time: 1.99s
# []
# None
# 0
# class: tie, score: 0.64
# box coordinate x,y,w,h: [373.06346893  59.66727734 159.16251183 412.18783379]
# 0
#
# time: 1.96s
# []
# None
# 0
# class: person, score: 0.74
# box coordinate x,y,w,h: [210.81924438  -0.9914875  410.68702698 489.20705795]
# 0
# class: tie, score: 0.70
# box coordinate x,y,w,h: [357.09072113  92.10481167 148.01267624 367.1294117 ]
# 0
#
# time: 1.95s
# []
# None
# 0
# class: person, score: 0.97
# box coordinate x,y,w,h: [ 23.65537643  90.02015591 485.13893127 385.02911568]
# 0
#
# time: 2.00s
# []
# None
# 0
# class: person, score: 0.88
# box coordinate x,y,w,h: [ 14.30570602 112.46892929 420.87673187 377.41361618]
# 0
# class: person, score: 0.72
# box coordinate x,y,w,h: [173.80588531  -5.09754181 474.02168274 485.14635086]
# 0
#
# time: 1.91s
# []
# None
# 0
# class: person, score: 0.95
# box coordinate x,y,w,h: [ 18.37614059  83.57531548 503.61671448 394.87873077]
# 0
# class: person, score: 0.67
# box coordinate x,y,w,h: [185.72511673  -6.37603283 455.91068268 490.83515167]
# 0
#
# time: 1.95s
# []
# None
# 0
# class: person, score: 0.95
# box coordinate x,y,w,h: [ 14.4443512   93.72387886 503.60702515 374.45955276]
# 0
# class: person, score: 0.79
# box coordinate x,y,w,h: [195.20015717  -6.53240204 433.4992981  489.86377716]
# 0
# class: person, score: 0.62
# box coordinate x,y,w,h: [502.79384613  19.91251945 140.18061638 443.85972977]
# 0
#
# time: 1.93s
# []
# None
# 0
# class: person, score: 0.82
# box coordinate x,y,w,h: [ 43.42617035  64.03321266 452.87033081 418.31096649]
# 0
#
# time: 1.94s
# []
# None
# 0
# class: person, score: 0.92
# box coordinate x,y,w,h: [ 34.05334473  61.53330803 466.59267426 421.34937286]
# 0
#
# time: 1.99s
# []
# None
# 0
# class: person, score: 0.90
# box coordinate x,y,w,h: [ 39.20518875  84.43117619 456.40224457 390.12059212]
# 0
# class: person, score: 0.70
# box coordinate x,y,w,h: [165.75035095  -1.88873291 235.4967308  339.65291977]
# 0
#
# time: 2.05s
# []
# None
# 0
# class: person, score: 0.71
# box coordinate x,y,w,h: [ -8.95246506  78.66818905 464.61040497 401.42180443]
# 0
# class: person, score: 0.70
# box coordinate x,y,w,h: [157.47096062   1.41420364 229.706707   339.10855293]
# 0
#
# time: 1.94s
# []
# None
# 0
# class: person, score: 0.96
# box coordinate x,y,w,h: [149.91718292  -4.98450279 253.64444733 344.02261734]
# 0
# class: person, score: 0.68
# box coordinate x,y,w,h: [ 30.3887558   73.35132122 472.59666443 414.58268166]
# 0
#
# time: 1.94s
# [36666]
# 0
# 0
# class: person, score: 0.88
# box coordinate x,y,w,h: [ 49.45516586  59.39114571 427.39028931 435.82494736]
# 0
# class: bottle, score: 0.68
# box coordinate x,y,w,h: [353.81511688 106.91225052 126.11284256 291.21694565]
# 1
#
# time: 1.94s
# []
# None
# 0
# class: person, score: 0.64
# box coordinate x,y,w,h: [154.88025665   1.9882822  445.91346741 477.19891548]
# 0
#
# time: 5.90s
# [20384]
# 0
# 0
# class: person, score: 0.98
# box coordinate x,y,w,h: [ 22.75093079  34.3650198  598.76464844 424.83235359]
# 0
# class: bottle, score: 0.62
# box coordinate x,y,w,h: [323.48617554 279.6007061  103.37687492 195.93963146]
# 1
#
# time: 3.30s
# []
# None
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [ 28.91202927  12.27054119 580.58979034 448.75628471]
# 0
#
# time: 2.77s
# []
# None
# 0
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 35.11322021  33.29913139 553.24092865 418.67265701]
# 0
#
# time: 2.35s
# []
# None
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [124.00209427   8.116436   490.20687103 464.59545135]
# 0
#
# time: 2.26s
# [19650]
# 0
# 0
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 12.07456589  21.55873775 379.10831451 438.77703667]
# 0
# class: person, score: 0.96
# box coordinate x,y,w,h: [318.11328888   2.4156189  326.04187012 480.82620621]
# 0
# class: bottle, score: 0.88
# box coordinate x,y,w,h: [344.00737762  82.68433571  75.13142586 262.36478806]
# 1
#
# time: 2.16s
# []
# None
# 0
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 10.240345    14.81878281 384.14047241 450.48065186]
# 0
# class: person, score: 0.82
# box coordinate x,y,w,h: [418.7940979   26.19116306 216.11745834 445.148592  ]
# 0
#
# time: 2.11s
# [20636]
# 0
# 0
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 20.11051178   4.45959091 378.7758255  468.20174217]
# 0
# class: bottle, score: 0.81
# box coordinate x,y,w,h: [321.5417099   81.78530216  77.37429619 268.28347206]
# 1
#
# time: 2.00s
# []
# None
# 0
# class: person, score: 1.00
# box coordinate x,y,w,h: [  7.08780289  13.02031517 408.41556549 448.30472946]
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [317.70187378  71.0158968  320.68435669 417.66497612]
# 0
#
# time: 1.98s
# []
# None
# 0
# class: person, score: 1.00
# box coordinate x,y,w,h: [  2.93613434  23.86811256 417.01023102 437.22570419]
# 0
# class: person, score: 1.00
# box coordinate x,y,w,h: [317.36585617  64.52693939 324.0581131  425.91876984]
# 0
#
# time: 2.04s
# []
# None
# 0
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 11.8406105    9.51285839 394.69490051 459.60047722]
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [312.06665039  63.19255829 321.07383728 429.62860107]
# 0
#
# time: 1.98s
# []
# None
# 0
# class: person, score: 1.00
# box coordinate x,y,w,h: [-10.59225082  12.19153404 391.64352417 448.18479538]
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [311.72250748  66.43228054 322.35912323 421.54515266]
# 0
#
# time: 1.98s
# []
# None
# 0
# class: person, score: 1.00
# box coordinate x,y,w,h: [  9.95397568  10.563941   395.38852692 462.68843651]
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [315.4262352   65.73181629 312.92102814 421.01351738]
# 0
#
# time: 1.99s
# []
# None
# 0
# class: person, score: 0.97
# box coordinate x,y,w,h: [  7.2505188    7.7964592  413.16318512 458.63176346]
# 0
# class: cell phone, score: 0.99
# box coordinate x,y,w,h: [276.89922333  88.07447433 189.8384285  227.50619888]
# 0
#
# time: 1.98s
# []
# None
# 0
# class: person, score: 1.00
# box coordinate x,y,w,h: [ -1.72369003   4.73051548 353.37841034 471.36746407]
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [306.03780746  59.68008041 332.65346527 408.49136353]
# 0
#
# time: 2.01s
# []
# None
# 0
# class: person, score: 0.98
# box coordinate x,y,w,h: [ 13.26356888  -3.29246521 397.87132263 488.7594223 ]
# 0
# class: person, score: 0.97
# box coordinate x,y,w,h: [309.46241379  54.42475319 329.28569794 420.52516937]
# 0
#
# time: 1.98s
# []
# None
# 0
# class: person, score: 0.97
# box coordinate x,y,w,h: [309.00671005  56.10882282 326.74068451 413.37521553]
# 0
# class: person, score: 0.95
# box coordinate x,y,w,h: [ 2.19919205e+01 -3.99398804e-01  3.76429405e+02  4.84860706e+02]
# 0
#
# time: 2.00s
# []
# None
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [312.58663177  67.29908466 324.39811707 402.16280937]
# 0
# class: person, score: 0.97
# box coordinate x,y,w,h: [ 21.82199478  -4.58129883 378.11813354 488.59628677]
# 0
#
# time: 2.01s
# []
# None
# 0
# class: person, score: 0.98
# box coordinate x,y,w,h: [299.21417236  61.81777954 344.52690125 408.40999603]
# 0
# class: person, score: 0.93
# box coordinate x,y,w,h: [ 26.81045532   1.1523056  377.61482239 485.12821198]
# 0
#
# time: 1.96s
# [41275]
# 0
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [301.67266846  68.48610878 341.41044617 401.21229172]
# 0
# class: person, score: 0.95
# box coordinate x,y,w,h: [ 20.94841003 -15.97423553 382.66700745 513.68900299]
# 0
# class: bottle, score: 0.65
# box coordinate x,y,w,h: [238.17644119  15.86515903 127.18852043 325.03252029]
# 1
#
# time: 2.01s
# [34226]
# 0
# 0
# class: person, score: 1.00
# box coordinate x,y,w,h: [-7.50940323e+00 -2.13503838e-01  3.70595512e+02  4.74234524e+02]
# 0
# class: person, score: 0.98
# box coordinate x,y,w,h: [382.56912231  62.24560261 257.97861099 416.14777565]
# 0
# class: bottle, score: 0.69
# box coordinate x,y,w,h: [220.63558578  81.29094601 109.31227684 314.16935921]
# 1
#
# time: 1.98s
# []
# None
# 0
# class: person, score: 0.98
# box coordinate x,y,w,h: [-4.97817993e-03  5.41833401e+00  3.60347328e+02  4.72316179e+02]
# 0
#
# time: 1.98s
# [34238]
# 0
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [ 29.9581337   -1.08653069 353.69029999 479.75458145]
# 0
# class: bottle, score: 0.72
# box coordinate x,y,w,h: [247.69083023  72.02633858 106.08664513 323.15425873]
# 1
#
# time: 2.00s
# [37278]
# 0
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [ -2.99674988  -3.1173563  374.35604095 478.95441055]
# 0
# class: bottle, score: 0.84
# box coordinate x,y,w,h: [235.33245087  49.38672066 113.6523056  326.69071198]
# 1
#
# time: 1.95s
# [36519]
# 0
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [3.05175781e-03 9.99784470e-02 3.71026955e+02 4.69352932e+02]
# 0
# class: chair, score: 0.72
# box coordinate x,y,w,h: [335.12310028 238.43791008 281.04888916 247.62737274]
# 0
# class: bottle, score: 0.93
# box coordinate x,y,w,h: [236.61472321  48.75762463 111.1060524  328.89372826]
# 1
#
# time: 1.96s
# [37856]
# 0
# 0
# class: person, score: 0.96
# box coordinate x,y,w,h: [  1.26573563   3.04793358 363.69777679 470.38252831]
# 0
# class: bottle, score: 0.86
# box coordinate x,y,w,h: [235.6697464   35.30283451 112.26675034 337.20760345]
# 1
#
# time: 2.01s
# []
# None
# 0
# class: person, score: 0.72
# box coordinate x,y,w,h: [ 57.22126007   0.8077383  440.7043457  475.39838791]
# 0
#
# time: 1.98s
# [39897, 30668]
# 0
# 0
# class: person, score: 0.98
# box coordinate x,y,w,h: [ 21.8504715   -3.27691555 385.87654114 473.68680954]
# 0
# class: bottle, score: 0.97
# box coordinate x,y,w,h: [314.91815567 172.81248093 143.4204483  279.16557312]
# 1
# class: bottle, score: 0.75
# box coordinate x,y,w,h: [263.38123322   7.35407352  81.4009285  373.23191643]
# 2
#
# time: 1.97s
# [52785, 27550]
# 0
# 0
# class: person, score: 0.98
# box coordinate x,y,w,h: [  2.53765106  -9.56358433 337.07424164 354.62659836]
# 0
# class: bottle, score: 0.95
# box coordinate x,y,w,h: [ 95.56461334 101.38405323 153.62609863 345.00025749]
# 1
# class: bottle, score: 0.70
# box coordinate x,y,w,h: [264.42176819  65.94760895  94.44688797 290.48727036]
# 2
#
# time: 2.08s
# [43092, 33899]
# 0
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [ 87.15106964 -25.9440136  360.5537796  466.59845352]
# 0
# class: bottle, score: 0.99
# box coordinate x,y,w,h: [130.9976387  103.01748276 126.06033325 341.86300278]
# 1
# class: bottle, score: 0.97
# box coordinate x,y,w,h: [259.71904755 157.33131409 109.37615395 310.35495758]
# 2
#
# time: 2.24s
# [48162, 37375]
# 0
# 0
# class: person, score: 0.84
# box coordinate x,y,w,h: [ 63.15002441 -13.8929987  403.39313507 439.26638603]
# 0
# class: bottle, score: 0.99
# box coordinate x,y,w,h: [123.57290268  97.22873211 138.49385262 349.10433769]
# 1
# class: bottle, score: 0.96
# box coordinate x,y,w,h: [273.38539124 119.32438374 114.38239098 324.43797112]
# 2
#
# time: 2.29s
# [47415, 40440]
# 0
# 0
# class: person, score: 0.73
# box coordinate x,y,w,h: [ 50.3626442  -13.64825249 432.29084015 443.66031647]
# 0
# class: bottle, score: 1.00
# box coordinate x,y,w,h: [119.99419212 115.32259941 145.15775681 326.62267685]
# 1
# class: bottle, score: 0.97
# box coordinate x,y,w,h: [278.52258682 117.21078873 120.7738781  336.38345718]
# 2
#
# time: 2.35s
# [51107, 43307]
# 0
# 0
# class: person, score: 0.97
# box coordinate x,y,w,h: [ 90.24080276  -4.21480179 375.89008331 475.37781715]
# 0
# class: bottle, score: 0.99
# box coordinate x,y,w,h: [117.79306412 110.70622444 149.60468292 343.56805801]
# 1
# class: bottle, score: 0.94
# box coordinate x,y,w,h: [345.1663208  132.29902267 126.49389267 340.9806633 ]
# 2
#
# time: 2.26s
# [46472, 45360]
# 0
# 0
# class: person, score: 0.71
# box coordinate x,y,w,h: [ 69.64120865   6.24278069 406.36306763 322.47528076]
# 0
# class: bottle, score: 1.00
# box coordinate x,y,w,h: [111.27285957 135.40474892 156.8588829  295.10427475]
# 1
# class: bottle, score: 0.95
# box coordinate x,y,w,h: [355.07980347 141.44019127 134.79101181 335.0762558 ]
# 2
#
# time: 1.95s
# [45450]
# 0
# 0
# class: person, score: 0.96
# box coordinate x,y,w,h: [ 92.97864914   2.70589828 371.05373383 461.30573273]
# 0
# class: person, score: 0.63
# box coordinate x,y,w,h: [ -2.03134537  -2.7780962  151.97721481 404.43746567]
# 0
# class: bottle, score: 1.00
# box coordinate x,y,w,h: [116.22109413 157.41499901 150.08516312 302.74171829]
# 1
#
# time: 2.00s
# [47084, 47538]
# 1
# 0
# class: person, score: 0.82
# box coordinate x,y,w,h: [ 70.86849213   1.95477962 410.69561005 471.76683426]
# 0
# class: bottle, score: 1.00
# box coordinate x,y,w,h: [114.07066345 149.41851139 148.43270302 315.85083961]
# 1
# class: bottle, score: 0.93
# box coordinate x,y,w,h: [331.71615601 131.67759418 139.24819946 341.9363308 ]
# 2
#
# time: 1.95s
# [50715, 42120]
# 0
# 0
# class: person, score: 0.91
# box coordinate x,y,w,h: [ 53.06154251  -1.41444683 433.05339813 339.82712746]
# 0
# class: chair, score: 0.88
# box coordinate x,y,w,h: [341.0477066  235.39833069 251.22413635 249.55369949]
# 0
# class: bottle, score: 0.98
# box coordinate x,y,w,h: [ 98.00266266 101.26336098 146.54484749 344.32617188]
# 1
# class: bottle, score: 0.95
# box coordinate x,y,w,h: [203.29978943 118.11015129 129.60283279 324.34633255]
# 2
#
# time: 1.94s
# [47047, 42315]
# 0
# 0
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 85.58864594  11.62555218 454.60720062 448.3246994 ]
# 0
# class: bottle, score: 0.99
# box coordinate x,y,w,h: [ 98.18716049 144.63855743 142.86678314 329.11502838]
# 1
# class: bottle, score: 0.76
# box coordinate x,y,w,h: [392.65918732 280.97465515 217.58674622 195.23780823]
# 2
#
# time: 1.96s
# []
# None
# 0
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 75.14024734  13.07126999 498.7707901  459.6717453 ]
# 0
#
# time: 1.94s
# []
# None
# 0
# class: person, score: 1.00
# box coordinate x,y,w,h: [156.75069809  28.53183746 446.91280365 423.81671906]
# 0
# class: person, score: 0.98
# box coordinate x,y,w,h: [  9.78066444   3.06585789 191.2575531  472.66387939]
# 0
#
# time: 1.98s
# []
# None
# 0
# class: person, score: 1.00
# box coordinate x,y,w,h: [224.03404236  19.1477108  392.71324158 446.0486412 ]
# 0
# class: person, score: 0.83
# box coordinate x,y,w,h: [  1.00815773   8.81665707 253.48033905 459.90022659]
# 0
#
# time: 2.07s
# []
# None
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [ -0.96065521   9.29228783 235.86154938 466.13061905]
# 0
# class: person, score: 0.93
# box coordinate x,y,w,h: [241.24769211  10.66872597 370.50510406 457.31045723]
# 0
#
# time: 1.96s
# []
# None
# 0
# class: person, score: 0.96
# box coordinate x,y,w,h: [ -4.21124458   2.83008099 220.65731049 472.804842  ]
# 0
# class: person, score: 0.89
# box coordinate x,y,w,h: [417.61398315  16.49820328 220.47298431 444.82194901]
# 0
# class: chair, score: 0.80
# box coordinate x,y,w,h: [325.5235672  232.66239166 195.50178528 252.99390793]
# 0
#
# time: 1.94s
# []
# None
# 0
# class: person, score: 0.96
# box coordinate x,y,w,h: [ -0.85450172   9.51244354 320.7195282  465.24782181]
# 0
# class: person, score: 0.88
# box coordinate x,y,w,h: [424.65442657   5.6269455  216.00889206 461.47075653]
# 0
# class: chair, score: 0.95
# box coordinate x,y,w,h: [331.88121796 233.11148643 177.84662247 253.92505646]
# 0
#
# time: 1.96s
# []
# None
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [122.11341858   4.12559509 501.79771423 469.05564308]
# 0
#
# time: 2.01s
# []
# None
# 0
# class: person, score: 0.98
# box coordinate x,y,w,h: [421.50115967   9.10835266 217.31266022 455.34871101]
# 0
# class: person, score: 0.97
# box coordinate x,y,w,h: [ 72.11898804  19.20205593 226.2846756  451.98592186]
# 0
# class: chair, score: 0.94
# box coordinate x,y,w,h: [338.98384094 237.89525986 157.6080513  248.40208054]
# 0
#
# time: 2.00s
# []
# None
# 0
# class: person, score: 0.98
# box coordinate x,y,w,h: [406.6885376    5.34039974 236.56141281 471.86997414]
# 0
# class: person, score: 0.70
# box coordinate x,y,w,h: [ -3.11037064   1.31559849 134.31563377 473.31075668]
# 0
# class: chair, score: 0.98
# box coordinate x,y,w,h: [336.36550903 237.86192894 164.37681198 248.75741959]
# 0
#
# time: 2.03s
# []
# None
# 0
# class: person, score: 0.94
# box coordinate x,y,w,h: [ -6.7244339    7.78369904 256.24389648 459.643507  ]
# 0
# class: person, score: 0.87
# box coordinate x,y,w,h: [490.52467346   6.33393288 147.15332031 469.45638657]
# 0
# class: chair, score: 0.91
# box coordinate x,y,w,h: [334.70836639 235.25619507 195.84241867 254.16172028]
# 0
#
# time: 2.02s
# []
# None
# 0
# class: person, score: 0.96
# box coordinate x,y,w,h: [-12.63961792  14.09500122 346.47628784 449.4923687 ]
# 0
# class: chair, score: 0.82
# box coordinate x,y,w,h: [326.2651825  237.13703156 215.28339386 248.7023735 ]
# 0
#
# time: 2.33s
# []
# None
# 0
# class: person, score: 0.99
# box coordinate x,y,w,h: [145.03837585  20.99005222 456.62338257 437.4626255 ]
# 0
# class: person, score: 0.64
# box coordinate x,y,w,h: [ -2.88023949  15.31658649 237.17325211 455.61432838]
# 0
#
# time: 2.32s
# []
# None
# 0
# class: person, score: 0.86
# box coordinate x,y,w,h: [ 41.76271439  11.84841156 552.27455139 458.05921555]
# 0
#
# time: 1.99s
# []
# None
# 0
# class: person, score: 0.86
# box coordinate x,y,w,h: [ 26.61617279  15.09490013 558.95572662 445.44161797]
# 0
#
# time: 1.95s
# time: 1.97s
# time: 2.02s
# []
# None
# 0
# class: person, score: 0.86
# box coordinate x,y,w,h: [ 71.48557663  28.21433544 523.58661652 434.42851067]
# 0

# %%
all_classes = get_classes(file)

# %%
all_classes = ['bottle']

# %%
cv2.destroyAllWindows()
camera.release()

# %%
list1 = [1,2,4,3,2]

# %%
list1[0]
# Out:
# (0, 0, 0, 1)

# %%
list1.append((0,0,0,3))

# %%
list1
# Out:
# [(0, 0, 0, 1), (0, 0, 0, 2), (0, 0, 0, 3)]

# %%
list1.argmax()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-4d2720809de3> in <module>
# ----> 1 list1.argmax()
#
# AttributeError: 'list' object has no attribute 'argmax'

# %%
1 == 1
# Out:
# True

# %%
list1 = []
len(list1)
# Out:
# 0

# %%
camera.release()
